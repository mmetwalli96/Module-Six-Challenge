# %%
# Importing Required Libraries and Modules

import random
import numpy as np
import pandas as pd
import requests
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitudes and longitudes combinations

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lats_lngs_combination = zip(lats, lngs)

# Add the latitudes and longitudes to a list to unzip the coordinates
coordinates = list(lats_lngs_combination)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# API URL
url = 'http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=' + weather_api_key 

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url  + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khromtau
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | berea
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | mount gambier
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | luwuk
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | goderich
# Processing Record 13 of Set 1 | pisco
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | coquimbo
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | isangel
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | prince rupert
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | selty
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | quelimane
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | boa vista
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | bandarbeyla
# Processing Record 34 of Set 1 | fukue
# Processing Record 35 of Set 1 | marienburg
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | hami
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | hualmay
# Processing Record 42 of Set 1 | burica
# City not found. Skipping...
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | tailai
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | angoche
# Processing Record 47 of Set 1 | andrushivka
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | tilichiki
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | montepuez
# Processing Record 3 of Set 2 | port arthur
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | sabang
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | marrakesh
# Processing Record 12 of Set 2 | khutar
# Processing Record 13 of Set 2 | wa
# City not found. Skipping...
# Processing Record 14 of Set 2 | flinders
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | naze
# Processing Record 21 of Set 2 | port hedland
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | avera
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | soyo
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | komsomolskiy
# Processing Record 29 of Set 2 | minab
# Processing Record 30 of Set 2 | ancud
# Processing Record 31 of Set 2 | turka
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | birao
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | port hardy
# Processing Record 37 of Set 2 | entre rios
# Processing Record 38 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 2 | menongue
# Processing Record 40 of Set 2 | padang
# Processing Record 41 of Set 2 | ust-kan
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | naifaru
# Processing Record 44 of Set 2 | borogontsy
# Processing Record 45 of Set 2 | zyryanka
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | nome
# Processing Record 48 of Set 2 | idlib
# Processing Record 49 of Set 2 | sisimiut
# Processing Record 50 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 3 | cairns
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | pustoshka
# Processing Record 4 of Set 3 | aswan
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | aracatuba
# Processing Record 8 of Set 3 | yerofey pavlovich
# Processing Record 9 of Set 3 | dire
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | baturaja
# Processing Record 12 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | chumikan
# Processing Record 15 of Set 3 | xining
# Processing Record 16 of Set 3 | griffith
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | brenham
# Processing Record 19 of Set 3 | cherskiy
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | feni
# Processing Record 22 of Set 3 | vila franca do campo
# Processing Record 23 of Set 3 | aklavik
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | alice springs
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | makakilo city
# Processing Record 28 of Set 3 | punta arenas
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | asuncion
# Processing Record 31 of Set 3 | xiamen
# Processing Record 32 of Set 3 | nordby
# Processing Record 33 of Set 3 | lata
# Processing Record 34 of Set 3 | kabanjahe
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | burns lake
# Processing Record 37 of Set 3 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 38 of Set 3 | kahului
# Processing Record 39 of Set 3 | cuiluan
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | oktyabrskiy
# Processing Record 42 of Set 3 | vikulovo
# Processing Record 43 of Set 3 | acapulco
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | mount isa
# Processing Record 47 of Set 3 | kysyl-syr
# Processing Record 48 of Set 3 | dingzhou
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | machali
# Processing Record 1 of Set 4 | finschhafen
# Processing Record 2 of Set 4 | teahupoo
# Processing Record 3 of Set 4 | brcko
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | lebyazhye
# Processing Record 7 of Set 4 | waddan
# Processing Record 8 of Set 4 | hobyo
# Processing Record 9 of Set 4 | ixtapa
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | tura
# Processing Record 13 of Set 4 | petropavlovka
# Processing Record 14 of Set 4 | mishan
# Processing Record 15 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 4 | cayenne
# Processing Record 17 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | sibolga
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | san javier
# Processing Record 22 of Set 4 | nisia floresta
# Processing Record 23 of Set 4 | hilo
# Processing Record 24 of Set 4 | hokitika
# Processing Record 25 of Set 4 | bid
# City not found. Skipping...
# Processing Record 26 of Set 4 | cape elizabeth
# City not found. Skipping...
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | yaring
# Processing Record 29 of Set 4 | richards bay
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | shakawe
# Processing Record 33 of Set 4 | alihe
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | timmins
# Processing Record 36 of Set 4 | geelong
# Processing Record 37 of Set 4 | cape town
# Processing Record 38 of Set 4 | kodiak
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | yeppoon
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | doha
# Processing Record 43 of Set 4 | necochea
# Processing Record 44 of Set 4 | manono
# Processing Record 45 of Set 4 | pitimbu
# Processing Record 46 of Set 4 | svetlogorsk
# Processing Record 47 of Set 4 | daru
# Processing Record 48 of Set 4 | koumac
# Processing Record 49 of Set 4 | aguadilla
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | ca mau
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | korla
# Processing Record 5 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 6 of Set 5 | penzance
# Processing Record 7 of Set 5 | esperance
# Processing Record 8 of Set 5 | egvekinot
# Processing Record 9 of Set 5 | constantine
# Processing Record 10 of Set 5 | misratah
# Processing Record 11 of Set 5 | liverpool
# Processing Record 12 of Set 5 | iwanai
# Processing Record 13 of Set 5 | lazaro cardenas
# Processing Record 14 of Set 5 | sapele
# Processing Record 15 of Set 5 | cabadiangan
# Processing Record 16 of Set 5 | azad shahr
# Processing Record 17 of Set 5 | ziyang
# Processing Record 18 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 5 | mahibadhoo
# Processing Record 20 of Set 5 | leninskoye
# Processing Record 21 of Set 5 | eura
# Processing Record 22 of Set 5 | kharp
# Processing Record 23 of Set 5 | rameswaram
# Processing Record 24 of Set 5 | atka
# City not found. Skipping...
# Processing Record 25 of Set 5 | batemans bay
# Processing Record 26 of Set 5 | maraa
# Processing Record 27 of Set 5 | general cepeda
# Processing Record 28 of Set 5 | willowmore
# Processing Record 29 of Set 5 | shelburne
# Processing Record 30 of Set 5 | port elizabeth
# Processing Record 31 of Set 5 | noyabrsk
# Processing Record 32 of Set 5 | codrington
# Processing Record 33 of Set 5 | okha
# Processing Record 34 of Set 5 | shellbrook
# Processing Record 35 of Set 5 | champerico
# Processing Record 36 of Set 5 | waingapu
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | mannarakkat
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | vyartsilya
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | sirur
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | mogadishu
# Processing Record 45 of Set 5 | tromso
# Processing Record 46 of Set 5 | carauari
# Processing Record 47 of Set 5 | providencia
# Processing Record 48 of Set 5 | ushtobe
# Processing Record 49 of Set 5 | sal rei
# Processing Record 50 of Set 5 | ulladulla
# Processing Record 1 of Set 6 | namibe
# Processing Record 2 of Set 6 | lielvarde
# Processing Record 3 of Set 6 | broome
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | gull lake
# Processing Record 6 of Set 6 | tasiilaq
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | mikkeli
# Processing Record 9 of Set 6 | khatanga
# Processing Record 10 of Set 6 | ranchuelo
# Processing Record 11 of Set 6 | emerald
# Processing Record 12 of Set 6 | asau
# Processing Record 13 of Set 6 | krugersdorp
# Processing Record 14 of Set 6 | moose factory
# Processing Record 15 of Set 6 | mehrabpur
# Processing Record 16 of Set 6 | puksoozero
# Processing Record 17 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 6 | imuris
# Processing Record 19 of Set 6 | kot diji
# Processing Record 20 of Set 6 | mikhaylovka
# Processing Record 21 of Set 6 | bethel
# Processing Record 22 of Set 6 | tongzi
# Processing Record 23 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 25 of Set 6 | torrijos
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | la estancia
# Processing Record 29 of Set 6 | mirnyy
# Processing Record 30 of Set 6 | sechura
# Processing Record 31 of Set 6 | buraydah
# Processing Record 32 of Set 6 | coihaique
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | porto novo
# Processing Record 36 of Set 6 | saint-joseph
# Processing Record 37 of Set 6 | khelyulya
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | goundi
# Processing Record 40 of Set 6 | najran
# Processing Record 41 of Set 6 | dezhou
# Processing Record 42 of Set 6 | plouzane
# Processing Record 43 of Set 6 | bilibino
# Processing Record 44 of Set 6 | xichang
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | klaksvik
# Processing Record 47 of Set 6 | santa cruz
# Processing Record 48 of Set 6 | banjar
# Processing Record 49 of Set 6 | cap malheureux
# Processing Record 50 of Set 6 | saint anthony
# Processing Record 1 of Set 7 | havoysund
# Processing Record 2 of Set 7 | karasjok
# Processing Record 3 of Set 7 | hof
# Processing Record 4 of Set 7 | aginskoye
# Processing Record 5 of Set 7 | tunggol
# Processing Record 6 of Set 7 | sitka
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | neuenrade
# Processing Record 9 of Set 7 | beloha
# Processing Record 10 of Set 7 | saldanha
# Processing Record 11 of Set 7 | athikia
# Processing Record 12 of Set 7 | issenye
# Processing Record 13 of Set 7 | krasnoyarskiy
# Processing Record 14 of Set 7 | bo
# City not found. Skipping...
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | adrar
# Processing Record 17 of Set 7 | fairbanks
# Processing Record 18 of Set 7 | fortuna
# Processing Record 19 of Set 7 | makinsk
# Processing Record 20 of Set 7 | nikolskoye
# Processing Record 21 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 7 | bengkulu
# Processing Record 23 of Set 7 | saryg-sep
# Processing Record 24 of Set 7 | montbrison
# Processing Record 25 of Set 7 | gunnedah
# Processing Record 26 of Set 7 | general roca
# Processing Record 27 of Set 7 | arman
# Processing Record 28 of Set 7 | merauke
# Processing Record 29 of Set 7 | kununurra
# Processing Record 30 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 7 | la ronge
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | llanes
# Processing Record 34 of Set 7 | ouargaye
# Processing Record 35 of Set 7 | guiratinga
# Processing Record 36 of Set 7 | grindavik
# Processing Record 37 of Set 7 | gus-zheleznyy
# Processing Record 38 of Set 7 | dingle
# Processing Record 39 of Set 7 | kapoeta
# Processing Record 40 of Set 7 | belyy yar
# Processing Record 41 of Set 7 | mayo
# Processing Record 42 of Set 7 | macapa
# Processing Record 43 of Set 7 | rio grande
# Processing Record 44 of Set 7 | moree
# Processing Record 45 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | alyangula
# Processing Record 48 of Set 7 | naryan-mar
# Processing Record 49 of Set 7 | lucapa
# Processing Record 50 of Set 7 | searcy
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 2 of Set 8 | shimoda
# Processing Record 3 of Set 8 | cedar city
# Processing Record 4 of Set 8 | paamiut
# Processing Record 5 of Set 8 | chivilcoy
# Processing Record 6 of Set 8 | santa maria
# Processing Record 7 of Set 8 | burkhala
# City not found. Skipping...
# Processing Record 8 of Set 8 | scalea
# Processing Record 9 of Set 8 | barentu
# Processing Record 10 of Set 8 | balti
# Processing Record 11 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 8 | the valley
# Processing Record 13 of Set 8 | koulikoro
# Processing Record 14 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 8 | kot putli
# City not found. Skipping...
# Processing Record 16 of Set 8 | the pas
# Processing Record 17 of Set 8 | wamba
# Processing Record 18 of Set 8 | lagoa
# Processing Record 19 of Set 8 | yarada
# Processing Record 20 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | tefe
# Processing Record 23 of Set 8 | stephenville
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | asfi
# Processing Record 26 of Set 8 | balsas
# Processing Record 27 of Set 8 | margate
# Processing Record 28 of Set 8 | antalaha
# Processing Record 29 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 8 | buchanan
# Processing Record 31 of Set 8 | birjand
# Processing Record 32 of Set 8 | fare
# Processing Record 33 of Set 8 | les cayes
# Processing Record 34 of Set 8 | qui nhon
# Processing Record 35 of Set 8 | wodonga
# Processing Record 36 of Set 8 | bandrele
# Processing Record 37 of Set 8 | chamba
# Processing Record 38 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 39 of Set 8 | baoma
# Processing Record 40 of Set 8 | eydhafushi
# Processing Record 41 of Set 8 | harindanga
# Processing Record 42 of Set 8 | lasa
# Processing Record 43 of Set 8 | waipawa
# Processing Record 44 of Set 8 | staritsa
# Processing Record 45 of Set 8 | tolaga bay
# Processing Record 46 of Set 8 | ratnagiri
# Processing Record 47 of Set 8 | axim
# Processing Record 48 of Set 8 | mount darwin
# Processing Record 49 of Set 8 | kovernino
# Processing Record 50 of Set 8 | shuangyang
# Processing Record 1 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 9 | sao jose da coroa grande
# Processing Record 3 of Set 9 | los llanos de aridane
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | altamont
# Processing Record 6 of Set 9 | la macarena
# Processing Record 7 of Set 9 | goksun
# Processing Record 8 of Set 9 | portland
# Processing Record 9 of Set 9 | chimbote
# Processing Record 10 of Set 9 | skjervoy
# Processing Record 11 of Set 9 | rakaia
# Processing Record 12 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 13 of Set 9 | quatre cocos
# Processing Record 14 of Set 9 | souillac
# Processing Record 15 of Set 9 | gumrak
# Processing Record 16 of Set 9 | roald
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | banda aceh
# Processing Record 19 of Set 9 | slave lake
# Processing Record 20 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 9 | ostrovnoy
# Processing Record 22 of Set 9 | sungaipenuh
# Processing Record 23 of Set 9 | bonthe
# Processing Record 24 of Set 9 | acarau
# Processing Record 25 of Set 9 | neya
# Processing Record 26 of Set 9 | nibbar
# Processing Record 27 of Set 9 | san quintin
# Processing Record 28 of Set 9 | kholodnyy
# Processing Record 29 of Set 9 | lexington
# Processing Record 30 of Set 9 | yaan
# Processing Record 31 of Set 9 | plettenberg bay
# Processing Record 32 of Set 9 | chernyshevskiy
# Processing Record 33 of Set 9 | galesong
# Processing Record 34 of Set 9 | otjiwarongo
# Processing Record 35 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 36 of Set 9 | sanary-sur-mer
# Processing Record 37 of Set 9 | uchiza
# Processing Record 38 of Set 9 | pinega
# Processing Record 39 of Set 9 | northfield
# Processing Record 40 of Set 9 | solnechnyy
# Processing Record 41 of Set 9 | rathenow
# Processing Record 42 of Set 9 | vasilsursk
# Processing Record 43 of Set 9 | mozarlandia
# Processing Record 44 of Set 9 | pangnirtung
# Processing Record 45 of Set 9 | lindi
# Processing Record 46 of Set 9 | sao filipe
# Processing Record 47 of Set 9 | kurchum
# Processing Record 48 of Set 9 | tessalit
# Processing Record 49 of Set 9 | dharchula
# Processing Record 50 of Set 9 | namatanai
# Processing Record 1 of Set 10 | hope
# Processing Record 2 of Set 10 | parana
# Processing Record 3 of Set 10 | westport
# Processing Record 4 of Set 10 | yumen
# Processing Record 5 of Set 10 | spas-demensk
# Processing Record 6 of Set 10 | maniitsoq
# Processing Record 7 of Set 10 | fengzhen
# Processing Record 8 of Set 10 | inirida
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | kenai
# Processing Record 11 of Set 10 | hasaki
# Processing Record 12 of Set 10 | paka
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | faya
# Processing Record 16 of Set 10 | tautira
# Processing Record 17 of Set 10 | dauphin
# Processing Record 18 of Set 10 | atar
# Processing Record 19 of Set 10 | santa lucia
# Processing Record 20 of Set 10 | great yarmouth
# Processing Record 21 of Set 10 | wadi musa
# Processing Record 22 of Set 10 | khudumelapye
# Processing Record 23 of Set 10 | srednekolymsk
# Processing Record 24 of Set 10 | bani
# Processing Record 25 of Set 10 | tucuman
# Processing Record 26 of Set 10 | maldonado
# Processing Record 27 of Set 10 | puri
# Processing Record 28 of Set 10 | alta floresta
# Processing Record 29 of Set 10 | praia
# Processing Record 30 of Set 10 | bealanana
# Processing Record 31 of Set 10 | gazanjyk
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | iskateley
# Processing Record 35 of Set 10 | talnakh
# Processing Record 36 of Set 10 | forbes
# Processing Record 37 of Set 10 | sola
# Processing Record 38 of Set 10 | maua
# Processing Record 39 of Set 10 | rorvik
# Processing Record 40 of Set 10 | hambantota
# Processing Record 41 of Set 10 | mirabad
# Processing Record 42 of Set 10 | huarmey
# Processing Record 43 of Set 10 | altay
# Processing Record 44 of Set 10 | culiacan
# Processing Record 45 of Set 10 | dicabisagan
# Processing Record 46 of Set 10 | dalvik
# Processing Record 47 of Set 10 | yar-sale
# Processing Record 48 of Set 10 | dayong
# Processing Record 49 of Set 10 | neiafu
# Processing Record 50 of Set 10 | karla
# Processing Record 1 of Set 11 | boende
# Processing Record 2 of Set 11 | gamba
# Processing Record 3 of Set 11 | nantucket
# Processing Record 4 of Set 11 | kaoma
# Processing Record 5 of Set 11 | poya
# Processing Record 6 of Set 11 | malayal
# Processing Record 7 of Set 11 | nogliki
# Processing Record 8 of Set 11 | gubskaya
# Processing Record 9 of Set 11 | vostok
# Processing Record 10 of Set 11 | nortelandia
# Processing Record 11 of Set 11 | kehychivka
# Processing Record 12 of Set 11 | pakxan
# Processing Record 13 of Set 11 | santa rosalia
# Processing Record 14 of Set 11 | constitucion
# Processing Record 15 of Set 11 | neuquen
# Processing Record 16 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 11 | nouadhibou
# Processing Record 18 of Set 11 | qaqortoq
# Processing Record 19 of Set 11 | cabedelo
# Processing Record 20 of Set 11 | gat
# Processing Record 21 of Set 11 | kampene
# Processing Record 22 of Set 11 | urumqi
# Processing Record 23 of Set 11 | magadan
# Processing Record 24 of Set 11 | carutapera
# Processing Record 25 of Set 11 | buala
# Processing Record 26 of Set 11 | gawler
# Processing Record 27 of Set 11 | kirkuk
# Processing Record 28 of Set 11 | fallon
# Processing Record 29 of Set 11 | oranjestad
# Processing Record 30 of Set 11 | barra do garcas
# Processing Record 31 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 11 | hegra
# Processing Record 34 of Set 11 | wagga wagga
# Processing Record 35 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 36 of Set 11 | thyolo
# Processing Record 37 of Set 11 | aguimes
# Processing Record 38 of Set 11 | moron
# Processing Record 39 of Set 11 | ofunato
# Processing Record 40 of Set 11 | davenda
# Processing Record 41 of Set 11 | san carlos
# Processing Record 42 of Set 11 | muriwai beach
# Processing Record 43 of Set 11 | bowen
# Processing Record 44 of Set 11 | kangaatsiaq
# Processing Record 45 of Set 11 | iskandar
# Processing Record 46 of Set 11 | svilajnac
# Processing Record 47 of Set 11 | jeremie
# Processing Record 48 of Set 11 | marquette
# Processing Record 49 of Set 11 | anadyr
# Processing Record 50 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 12 | coahuayana
# Processing Record 2 of Set 12 | camargo
# Processing Record 3 of Set 12 | moyale
# Processing Record 4 of Set 12 | ejido
# Processing Record 5 of Set 12 | ayan
# Processing Record 6 of Set 12 | hirara
# Processing Record 7 of Set 12 | nanakuli
# Processing Record 8 of Set 12 | ruza
# Processing Record 9 of Set 12 | xian
# Processing Record 10 of Set 12 | biloela
# Processing Record 11 of Set 12 | zhigansk
# Processing Record 12 of Set 12 | port lincoln
# Processing Record 13 of Set 12 | jaitaran
# Processing Record 14 of Set 12 | khandyga
# Processing Record 15 of Set 12 | ambon
# Processing Record 16 of Set 12 | patea
# Processing Record 17 of Set 12 | manggar
# Processing Record 18 of Set 12 | tezu
# Processing Record 19 of Set 12 | chaochou
# City not found. Skipping...
# Processing Record 20 of Set 12 | rincon
# Processing Record 21 of Set 12 | santiago del estero
# Processing Record 22 of Set 12 | severnoye
# Processing Record 23 of Set 12 | volnovakha
# Processing Record 24 of Set 12 | hollins
# Processing Record 25 of Set 12 | san juan
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | chingirlau
# Processing Record 28 of Set 12 | hervey bay
# Processing Record 29 of Set 12 | lekoni
# Processing Record 30 of Set 12 | zhoucheng
# Processing Record 31 of Set 12 | oga
# Processing Record 32 of Set 12 | berlevag
# Processing Record 33 of Set 12 | hermiston
# Processing Record 34 of Set 12 | urengoy
# Processing Record 35 of Set 12 | kudahuvadhoo
# Processing Record 36 of Set 12 | hamilton
# Processing Record 37 of Set 12 | sakakah
# Processing Record 38 of Set 12 | kodinsk
# Processing Record 39 of Set 12 | sinnamary
# Processing Record 40 of Set 12 | mardin
# Processing Record 41 of Set 12 | magdagachi
# Processing Record 42 of Set 12 | tena
# Processing Record 43 of Set 12 | swan hill
# Processing Record 44 of Set 12 | abnub
# Processing Record 45 of Set 12 | coronado
# Processing Record 46 of Set 12 | ostrov
# Processing Record 47 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 12 | eyl
# Processing Record 49 of Set 12 | avila
# Processing Record 50 of Set 12 | beba
# Processing Record 1 of Set 13 | thurso
# Processing Record 2 of Set 13 | gizo
# Processing Record 3 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 13 | namtsy
# Processing Record 5 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 7 of Set 13 | san carlos de bariloche
# Processing Record 8 of Set 13 | henties bay
# Processing Record 9 of Set 13 | camopi
# Processing Record 10 of Set 13 | el porvenir
# Processing Record 11 of Set 13 | bagan
# Processing Record 12 of Set 13 | syracuse
# Processing Record 13 of Set 13 | zvishavane
# Processing Record 14 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 13 | ndioum
# Processing Record 16 of Set 13 | lorengau
# Processing Record 17 of Set 13 | kaspiyskiy
# Processing Record 18 of Set 13 | pontianak
# Processing Record 19 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 20 of Set 13 | mattru
# Processing Record 21 of Set 13 | xai-xai
# Processing Record 22 of Set 13 | pennagaram
# Processing Record 23 of Set 13 | brits
# Processing Record 24 of Set 13 | kalianget
# Processing Record 25 of Set 13 | bakel
# Processing Record 26 of Set 13 | ginir
# Processing Record 27 of Set 13 | fujin
# Processing Record 28 of Set 13 | parsabad
# Processing Record 29 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 30 of Set 13 | saint-georges
# Processing Record 31 of Set 13 | shizunai
# Processing Record 32 of Set 13 | cumpas
# Processing Record 33 of Set 13 | epe
# Processing Record 34 of Set 13 | taganak
# Processing Record 35 of Set 13 | mitu
# Processing Record 36 of Set 13 | san policarpo
# Processing Record 37 of Set 13 | karratha
# Processing Record 38 of Set 13 | zhovtneve
# Processing Record 39 of Set 13 | siocon
# Processing Record 40 of Set 13 | ahipara
# Processing Record 41 of Set 13 | suntar
# Processing Record 42 of Set 13 | inhambane
# Processing Record 43 of Set 13 | maltahohe
# Processing Record 44 of Set 13 | altamira
# Processing Record 45 of Set 13 | celestun
# Processing Record 46 of Set 13 | comodoro rivadavia
# Processing Record 47 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 13 | saint-pierre
# Processing Record 49 of Set 13 | kalemie
# Processing Record 50 of Set 13 | omboue
# Processing Record 1 of Set 14 | camacha
# Processing Record 2 of Set 14 | tabas
# Processing Record 3 of Set 14 | san andres
# Processing Record 4 of Set 14 | rio gallegos
# Processing Record 5 of Set 14 | puerto escondido
# Processing Record 6 of Set 14 | dargaville
# Processing Record 7 of Set 14 | quesnel
# Processing Record 8 of Set 14 | malanje
# Processing Record 9 of Set 14 | ternate
# Processing Record 10 of Set 14 | marzuq
# Processing Record 11 of Set 14 | smolyaninovo
# Processing Record 12 of Set 14 | ouro preto do oeste
# Processing Record 13 of Set 14 | selikhino
# Processing Record 14 of Set 14 | toumodi
# Processing Record 15 of Set 14 | kalashnikovo
# Processing Record 16 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 14 | laguna
# Processing Record 19 of Set 14 | varhaug
# Processing Record 20 of Set 14 | mitsamiouli
# Processing Record 21 of Set 14 | itarema
# Processing Record 22 of Set 14 | kericho
# Processing Record 23 of Set 14 | port macquarie
# Processing Record 24 of Set 14 | guerrero negro
# Processing Record 25 of Set 14 | olafsvik
# Processing Record 26 of Set 14 | turukhansk
# Processing Record 27 of Set 14 | la peca
# Processing Record 28 of Set 14 | reconquista
# Processing Record 29 of Set 14 | roma
# Processing Record 30 of Set 14 | hailey
# Processing Record 31 of Set 14 | lajedo
# Processing Record 32 of Set 14 | kruisfontein
# Processing Record 33 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 14 | shenjiamen
# Processing Record 35 of Set 14 | kandrian
# Processing Record 36 of Set 14 | gibara
# Processing Record 37 of Set 14 | georgiyevka
# Processing Record 38 of Set 14 | borovskoy
# Processing Record 39 of Set 14 | flin flon
# Processing Record 40 of Set 14 | fereydun kenar
# Processing Record 41 of Set 14 | mokolo
# Processing Record 42 of Set 14 | mezen
# Processing Record 43 of Set 14 | young
# Processing Record 44 of Set 14 | popondetta
# Processing Record 45 of Set 14 | baruun-urt
# Processing Record 46 of Set 14 | chicama
# Processing Record 47 of Set 14 | kaura namoda
# Processing Record 48 of Set 14 | tazovskiy
# Processing Record 49 of Set 14 | yaritagua
# Processing Record 50 of Set 14 | dhidhdhoo
# Processing Record 1 of Set 15 | dom pedrito
# Processing Record 2 of Set 15 | parrita
# Processing Record 3 of Set 15 | edson
# Processing Record 4 of Set 15 | plyussa
# Processing Record 5 of Set 15 | taoudenni
# Processing Record 6 of Set 15 | viedma
# Processing Record 7 of Set 15 | olga
# Processing Record 8 of Set 15 | michigan city
# Processing Record 9 of Set 15 | gold coast
# Processing Record 10 of Set 15 | te anau
# Processing Record 11 of Set 15 | oranjemund
# Processing Record 12 of Set 15 | upington
# Processing Record 13 of Set 15 | iberia
# Processing Record 14 of Set 15 | bucu
# Processing Record 15 of Set 15 | port said
# Processing Record 16 of Set 15 | malartic
# Processing Record 17 of Set 15 | kalofer
# Processing Record 18 of Set 15 | nyurba
# Processing Record 19 of Set 15 | mikun
# Processing Record 20 of Set 15 | kathu
# Processing Record 21 of Set 15 | spirit river
# Processing Record 22 of Set 15 | quime
# Processing Record 23 of Set 15 | yambio
# Processing Record 24 of Set 15 | filingue
# Processing Record 25 of Set 15 | biak
# Processing Record 26 of Set 15 | denpasar
# Processing Record 27 of Set 15 | lakatoro
# Processing Record 28 of Set 15 | choix
# Processing Record 29 of Set 15 | manokwari
# Processing Record 30 of Set 15 | umm lajj
# Processing Record 31 of Set 15 | college
# Processing Record 32 of Set 15 | shache
# Processing Record 33 of Set 15 | sistranda
# Processing Record 34 of Set 15 | agirish
# Processing Record 35 of Set 15 | macia
# Processing Record 36 of Set 15 | mbandaka
# Processing Record 37 of Set 15 | qujing
# Processing Record 38 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 39 of Set 15 | havelock
# Processing Record 40 of Set 15 | tazmalt
# Processing Record 41 of Set 15 | eureka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
